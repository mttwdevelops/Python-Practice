# %% [markdown]
# ## Created by MttwDevelops
# with tender love and care!

# %%
# Testing notebook
# Created 7/17/2022

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('facebook.csv')
df.head()
df.tail()

df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adjusted Close', 'Volume']
df.tail()
df.dtypes

# not exactly needed to group by date since it's just a single observation but you get the idea
thing = df.loc[:, ['Date', 'Low']].groupby("Date")
avgs = thing.mean()
x = avgs.index
y1 = avgs.Low
def plot(x, y, ax, title, y_label):
    ax.set_title(title)
    ax.set_ylabel(y_label)
    ax.plot(x,y)
    ax.margins(x=0,y=0)
fig, ax = plt.subplots()
plot(x,y1,ax, "facebook stock low graph", "low price per date")

# %%
df = pd.read_csv('microsoft.csv')
df.head()
df['Close']
df['difference'] = df['Close'] - df['Open']
df.info()
df.T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        64 non-null     object
#  1   Open        64 non-null     float64
#  2   High        64 non-null     float64
#  3   Low         64 non-null     float64
#  4   Close       64 non-null     float64
#  5   Adj Close   64 non-null     float64
#  6   Volume      64 non-null     int64
#  7   difference  64 non-null     float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 4.1+ KB
#                     0           1           2           3           4   \
# Date        2022-03-15  2022-03-16  2022-03-17  2022-03-18  2022-03-21
# Open        280.350006  289.109985  293.290009  295.369995  298.890015
# High        287.820007  294.570007  295.609985       301.0  300.140015
# Low         278.730011  283.200012  289.369995  292.730011  294.899994
# Close       287.149994  294.390015  295.220001  300.429993  299.160004
# Adj Close   286.482758  293.705933  294.533997  299.731873  298.464844
# Volume        34245100    37826300    30816600    43390600    28351200
# difference    6.799988     5.28003    1.929992    5.059998    0.269989
#
#                     5           6           7           8           9   ...  \
# Date        2022-03-22  2022-03-23  2022-03-24  2022-03-25  2022-03-28  ...
# Open        299.799988   300.51001  299.140015  305.230011  304.329987  ...
# High             305.0  303.230011  304.200012       305.5  310.799988  ...
# Low         298.769989  297.720001  298.320007  299.290009  304.329987  ...
# Close       304.059998   299.48999  304.100006  303.679993  310.700012  ...
# Adj Close   303.353455  298.794067  303.393372  302.974335  309.978058  ...
# Volume        27599700    25715400    24484500    22566500    29578200  ...
# difference     4.26001    -1.02002    4.959991   -1.550018    6.370025  ...
#
#                     54          55          56          57          58  \
# Date        2022-06-01  2022-06-02  2022-06-03  2022-06-06  2022-06-07
# Open        275.200012  264.450012  270.309998  272.059998  266.640015
# High        277.690002  274.649994  273.450012  274.179993  273.130005
# Low         270.040009  261.600006  268.410004  267.220001  265.940002
# Close       272.420013  274.579987  270.019989      268.75       272.5
# Adj Close   272.420013  274.579987  270.019989      268.75       272.5
# Volume        25292200    44008200    28048000    22400300    22860700
# difference   -2.779999   10.129975   -0.290009   -3.309998    5.859985
#
#                     59          60          61          62          63
# Date        2022-06-08  2022-06-09  2022-06-10  2022-06-13  2022-06-14
# Open        271.709991  267.779999  260.579987  245.110001  243.860001
# High             273.0  272.709991  260.579987  249.020004  245.740005
# Low         269.609985  264.630005  252.529999  241.529999  241.509995
# Close       270.410004  264.790009  252.990005  242.259995  244.490005
# Adj Close   270.410004  264.790009  252.990005  242.259995  244.490005
# Volume        17372300    26439700    31422800    46135800    28616700
# difference   -1.299987    -2.98999   -7.589982   -2.850006    0.630004
#
# [8 rows x 64 columns]
